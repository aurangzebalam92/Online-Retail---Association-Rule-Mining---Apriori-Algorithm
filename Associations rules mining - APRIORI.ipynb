# %%
#import libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
# set the working directory
os.chdir("E:/Data Science/Data Science/Edureka/Case Studies/5. Online Retails")

# %%
#Check the working directory
os.getcwd()
# Out:
# 'E:\\Data Science\\Data Science\\Edureka\\Case Studies\\5. Online Retails'

# %%
#Load the data
Dataset = pd.read_excel("Online Retail.xlsx")

# %%
#Top 5 rows
Dataset.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
#Columns
Dataset.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#shape
Dataset.shape
# Out:
# (541909, 8)

# %%
#Import Apriori and Association libraries
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
Dataset.dropna(axis=0,subset=["InvoiceNo"], inplace=True)

# %%
#Remove the credit transactions
Dataset["InvoiceNo"] = Dataset["InvoiceNo"].astype("str")
Dataset = Dataset[~Dataset["InvoiceNo"].str.contains("C")]

# %%
# This groupby keeps invoice number as row and product in column
Market_Basket = Dataset[Dataset["Country"]=="France"].groupby(["InvoiceNo","Description"])["Quantity"].sum().unstack().reset_index().fillna(0).set_index("InvoiceNo")

# %%
Market_Basket.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                  0.0                 0.0
# 536852                                  0.0                 0.0
# 536974                                  0.0                 0.0
# 537065                                  0.0                 0.0
# 537463                                  0.0                 0.0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                0.0                       0.0
# 536852                                0.0                       0.0
# 536974                                0.0                       0.0
# 537065                                0.0                       0.0
# 537463                                0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# ...

# %%
#Convert the values >1 = 1 and value = 0 to 0 so as to signify presence and absence of a product.
def conversion0to1(x):
    if x >= 1:
        return 1
    else:
        return 0
converted_market_basket = Market_Basket.applymap(conversion0to1)

# %%
converted_market_basket.drop("POSTAGE", inplace=True, axis=1)

# %%
converted_market_basket.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                    0                   0
# 536852                                    0                   0
# 536974                                    0                   0
# 537065                                    0                   0
# 537463                                    0                   0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                  0                         0
# 536852                                  0                         0
# 536974                                  0                         0
# 537065                                  0                         0
# 537463                                  0                         0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# ...

# %%
#Apriori algorithm
frequent_items = apriori(converted_market_basket, min_support = 0.07, use_colnames= True)
frequent_items
# Out:
#      support                                           itemsets
# 0   0.071429                      (4 TRADITIONAL SPINNING TOPS)
# 1   0.096939                       (ALARM CLOCK BAKELIKE GREEN)
# 2   0.102041                        (ALARM CLOCK BAKELIKE PINK)
# 3   0.094388                        (ALARM CLOCK BAKELIKE RED )
# 4   0.081633                    (BAKING SET 9 PIECE RETROSPOT )
# 5   0.071429                    (CHILDRENS CUTLERY DOLLY GIRL )
# 6   0.099490                             (DOLLY GIRL LUNCH BOX)
# 7   0.096939                          (JUMBO BAG RED RETROSPOT)
# 8   0.076531                       (JUMBO BAG WOODLAND ANIMALS)
# 9   0.125000                           (LUNCH BAG APPLE DESIGN)
# 10  0.084184                      (LUNCH BAG DOLLY GIRL DESIGN)
# 11  0.153061                          (LUNCH BAG RED RETROSPOT)
# 12  0.119898                       (LUNCH BAG SPACEBOY DESIGN )
# 13  0.117347                               (LUNCH BAG WOODLAND)
# ...

# %%
asso_rule = association_rules(frequent_items, metric="lift", min_threshold=1)

# %%
asso_rule.head()
# Out:
#                     antecedents                   consequents  \
# 0  (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE PINK)
# 1   (ALARM CLOCK BAKELIKE PINK)  (ALARM CLOCK BAKELIKE GREEN)
# 2   (ALARM CLOCK BAKELIKE RED )  (ALARM CLOCK BAKELIKE GREEN)
# 3  (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE RED )
# 4   (ALARM CLOCK BAKELIKE RED )   (ALARM CLOCK BAKELIKE PINK)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.096939            0.102041  0.073980    0.763158  7.478947
# 1            0.102041            0.096939  0.073980    0.725000  7.478947
# 2            0.094388            0.096939  0.079082    0.837838  8.642959
# 3            0.096939            0.094388  0.079082    0.815789  8.642959
# 4            0.094388            0.102041  0.073980    0.783784  7.681081
#
#    leverage  conviction
# 0  0.064088    3.791383
# 1  0.064088    3.283859
# 2  0.069932    5.568878
# 3  0.069932    4.916181
# ...
